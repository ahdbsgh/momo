# %%
import numpy as np
import pandas as pd

# %%
train_df = pd.read_csv(r'C:\Users\MOMOZZING\WorkSpace\momo\momo\kaggle\DATA\leaf-classification/train.csv')
test_df = pd.read_csv(r'C:\Users\MOMOZZING\WorkSpace\momo\momo\kaggle\DATA\leaf-classification/test.csv')

# %%
train_df
# Out:
#        id                species   margin1   margin2   margin3   margin4  \
# 0       1            Acer_Opalus  0.007812  0.023438  0.023438  0.003906
# 1       2  Pterocarya_Stenoptera  0.005859  0.000000  0.031250  0.015625
# 2       3   Quercus_Hartwissiana  0.005859  0.009766  0.019531  0.007812
# 3       5        Tilia_Tomentosa  0.000000  0.003906  0.023438  0.005859
# 4       6     Quercus_Variabilis  0.005859  0.003906  0.048828  0.009766
# ..    ...                    ...       ...       ...       ...       ...
# 985  1575   Magnolia_Salicifolia  0.060547  0.119140  0.007812  0.003906
# 986  1578            Acer_Pictum  0.001953  0.003906  0.021484  0.107420
# 987  1581     Alnus_Maximowiczii  0.001953  0.003906  0.000000  0.021484
# 988  1582          Quercus_Rubra  0.000000  0.000000  0.046875  0.056641
# 989  1584         Quercus_Afares  0.023438  0.019531  0.031250  0.015625
#
#       margin5   margin6   margin7  margin8  ...  texture55  texture56  \
# ...

# %%
test_df
# Out:
#        id   margin1   margin2   margin3   margin4   margin5   margin6  \
# 0       4  0.019531  0.009766  0.078125  0.011719  0.003906  0.015625
# 1       7  0.007812  0.005859  0.064453  0.009766  0.003906  0.013672
# 2       9  0.000000  0.000000  0.001953  0.021484  0.041016  0.000000
# 3      12  0.000000  0.000000  0.009766  0.011719  0.017578  0.000000
# 4      13  0.001953  0.000000  0.015625  0.009766  0.039062  0.000000
# ..    ...       ...       ...       ...       ...       ...       ...
# 589  1576  0.000000  0.000000  0.003906  0.015625  0.041016  0.000000
# 590  1577  0.000000  0.003906  0.003906  0.005859  0.017578  0.000000
# 591  1579  0.017578  0.029297  0.015625  0.013672  0.003906  0.015625
# 592  1580  0.013672  0.009766  0.060547  0.025391  0.035156  0.025391
# 593  1583  0.000000  0.117190  0.000000  0.019531  0.000000  0.136720
#
#       margin7   margin8   margin9  ...  texture55  texture56  texture57  \
# ...

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 990 entries, 0 to 989
# Columns: 194 entries, id to texture64
# dtypes: float64(192), int64(1), object(1)
# memory usage: 1.5+ MB

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 594 entries, 0 to 593
# Columns: 193 entries, id to texture64
# dtypes: float64(192), int64(1)
# memory usage: 895.8 KB

# %%
train_df.isnull().sum()
# Out:
# id           0
# species      0
# margin1      0
# margin2      0
# margin3      0
#             ..
# texture60    0
# texture61    0
# texture62    0
# texture63    0
# texture64    0
# Length: 194, dtype: int64

# %%
test_df.isnull().sum()
# Out:
# id           0
# margin1      0
# margin2      0
# margin3      0
# margin4      0
#             ..
# texture60    0
# texture61    0
# texture62    0
# texture63    0
# texture64    0
# Length: 193, dtype: int64

# %%
train_df.drop(['id'],axis=1,inplace=True)

# %%
test_df.drop(['id'],axis=1,inplace=True)

# %%
train_df
# Out:
#                    species   margin1   margin2   margin3   margin4   margin5  \
# 0              Acer_Opalus  0.007812  0.023438  0.023438  0.003906  0.011719
# 1    Pterocarya_Stenoptera  0.005859  0.000000  0.031250  0.015625  0.025391
# 2     Quercus_Hartwissiana  0.005859  0.009766  0.019531  0.007812  0.003906
# 3          Tilia_Tomentosa  0.000000  0.003906  0.023438  0.005859  0.021484
# 4       Quercus_Variabilis  0.005859  0.003906  0.048828  0.009766  0.013672
# ..                     ...       ...       ...       ...       ...       ...
# 985   Magnolia_Salicifolia  0.060547  0.119140  0.007812  0.003906  0.000000
# 986            Acer_Pictum  0.001953  0.003906  0.021484  0.107420  0.001953
# 987     Alnus_Maximowiczii  0.001953  0.003906  0.000000  0.021484  0.078125
# 988          Quercus_Rubra  0.000000  0.000000  0.046875  0.056641  0.009766
# 989         Quercus_Afares  0.023438  0.019531  0.031250  0.015625  0.005859
#
# ...

# %%
test_df
# Out:
#       margin1   margin2   margin3   margin4   margin5   margin6   margin7  \
# 0    0.019531  0.009766  0.078125  0.011719  0.003906  0.015625  0.005859
# 1    0.007812  0.005859  0.064453  0.009766  0.003906  0.013672  0.007812
# 2    0.000000  0.000000  0.001953  0.021484  0.041016  0.000000  0.023438
# 3    0.000000  0.000000  0.009766  0.011719  0.017578  0.000000  0.003906
# 4    0.001953  0.000000  0.015625  0.009766  0.039062  0.000000  0.009766
# ..        ...       ...       ...       ...       ...       ...       ...
# 589  0.000000  0.000000  0.003906  0.015625  0.041016  0.000000  0.017578
# 590  0.000000  0.003906  0.003906  0.005859  0.017578  0.000000  0.017578
# 591  0.017578  0.029297  0.015625  0.013672  0.003906  0.015625  0.025391
# 592  0.013672  0.009766  0.060547  0.025391  0.035156  0.025391  0.039062
# 593  0.000000  0.117190  0.000000  0.019531  0.000000  0.136720  0.001953
#
#       margin8   margin9  margin10  ...  texture55  texture56  texture57  \
# ...

# %%
Y = train_df['species']
Y
# Out:
# 0                Acer_Opalus
# 1      Pterocarya_Stenoptera
# 2       Quercus_Hartwissiana
# 3            Tilia_Tomentosa
# 4         Quercus_Variabilis
#                ...
# 985     Magnolia_Salicifolia
# 986              Acer_Pictum
# 987       Alnus_Maximowiczii
# 988            Quercus_Rubra
# 989           Quercus_Afares
# Name: species, Length: 990, dtype: object

# %%
train_df.drop(['species'],axis=1,inplace=True)

# %%
X = train_df

# %%
X
# Out:
#       margin1   margin2   margin3   margin4   margin5   margin6   margin7  \
# 0    0.007812  0.023438  0.023438  0.003906  0.011719  0.009766  0.027344
# 1    0.005859  0.000000  0.031250  0.015625  0.025391  0.001953  0.019531
# 2    0.005859  0.009766  0.019531  0.007812  0.003906  0.005859  0.068359
# 3    0.000000  0.003906  0.023438  0.005859  0.021484  0.019531  0.023438
# 4    0.005859  0.003906  0.048828  0.009766  0.013672  0.015625  0.005859
# ..        ...       ...       ...       ...       ...       ...       ...
# 985  0.060547  0.119140  0.007812  0.003906  0.000000  0.148440  0.017578
# 986  0.001953  0.003906  0.021484  0.107420  0.001953  0.000000  0.000000
# 987  0.001953  0.003906  0.000000  0.021484  0.078125  0.003906  0.007812
# 988  0.000000  0.000000  0.046875  0.056641  0.009766  0.000000  0.000000
# 989  0.023438  0.019531  0.031250  0.015625  0.005859  0.019531  0.035156
#
#      margin8   margin9  margin10  ...  texture55  texture56  texture57  \
# ...

# %%
test_df
# Out:
#       margin1   margin2   margin3   margin4   margin5   margin6   margin7  \
# 0    0.019531  0.009766  0.078125  0.011719  0.003906  0.015625  0.005859
# 1    0.007812  0.005859  0.064453  0.009766  0.003906  0.013672  0.007812
# 2    0.000000  0.000000  0.001953  0.021484  0.041016  0.000000  0.023438
# 3    0.000000  0.000000  0.009766  0.011719  0.017578  0.000000  0.003906
# 4    0.001953  0.000000  0.015625  0.009766  0.039062  0.000000  0.009766
# ..        ...       ...       ...       ...       ...       ...       ...
# 589  0.000000  0.000000  0.003906  0.015625  0.041016  0.000000  0.017578
# 590  0.000000  0.003906  0.003906  0.005859  0.017578  0.000000  0.017578
# 591  0.017578  0.029297  0.015625  0.013672  0.003906  0.015625  0.025391
# 592  0.013672  0.009766  0.060547  0.025391  0.035156  0.025391  0.039062
# 593  0.000000  0.117190  0.000000  0.019531  0.000000  0.136720  0.001953
#
#       margin8   margin9  margin10  ...  texture55  texture56  texture57  \
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
X_train, X_val, y_train, y_val = train_test_split(X, Y, test_size=0.3, random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier

rfc = RandomForestClassifier(max_depth=20, random_state=24)
rfc.fit(X_train, y_train)
rfc_pred = rfc.predict(X_val)
print("정확도:", accuracy_score(y_val, rfc_pred))
# Out:
# 정확도: 0.9595959595959596

# %%
final_rfc = rfc.predict(test)

# %%
from datetime import datetime

t = datetime.now().strftime('%Y-%m-%d-%H-%M') #파일이름에 작업시간넣기
filename = '{0}-rfc-submission.csv'.format(t)               #파일이름

print(filename)# 파일 이름확인
# Out:
# 2021-04-01-21-28-rfc-submission.csv

# %%
sample_submission = pd.read_csv(r'C:\Users\MOMOZZING\WorkSpace\momo\momo\kaggle\DATA\leaf-classification/sample_submission.csv') # 파일위치
final_prediction_rfc = final_rfc #예측결과 넣기

# %%
sample_submission['species'] = final_prediction_rfc #타겟값에 예측결과 넣기
sample_submission.to_csv(filename, index=False) #csv파일로 변환
